# %%
import beam as bm

# %%
import matplotlib.pyplot as plt

# %%
bm.change_default_parameter('decision', 'sw_mode', 'uniform')

# %% [markdown]
# __ansatz uniform__

# %%
bm.diagnostic_agent_decision()
# Out:
# testing agent decision:
# decision parameters:
#     def_d_max : 0.75
#     def_d_min : 0.25
#     def_b_min : 0.0
#     sw_mode : uniform
#     eta_coeff : 55
#     sw_coeff : eq_dist
#     sw_coeff_minmax : 0.02
#     sw_coeff_postmap : <function <lambda> at 0x000001379C239040>
#     price_fluct : 0.001
#     reference_price : last
#     subaction_par : 0.0
#   0%|          | 0/11 [00:00<?, ?it/s]
# C:\Users\Utente\Desktop\Beam\beam.py:3686: RuntimeWarning: Mean of empty slice.
#   pos_avg=np.array([val for val in sigma_new_theta[sigma_old] if val>0]).mean()
# C:\Users\Utente\anaconda3\envs\beam\lib\site-packages\numpy\core\_methods.py:170: RuntimeWarning: invalid value encountered in double_scalars
#   ret = ret.dtype.type(ret / rcount)
# C:\Users\Utente\Desktop\Beam\beam.py:3687: RuntimeWarning: Mean of empty slice.
#   neg_avg=np.array([val for val in sigma_new_theta[sigma_old] if val<0]).mean()

# %% [markdown]
# __ansatz beta__

# %%
bm.change_default_parameter('decision', 'sw_mode', 'beta')

# %%
bm.diagnostic_agent_decision()
# Out:
# testing agent decision:
# decision parameters:
#     def_d_max : 0.75
#     def_d_min : 0.25
#     def_b_min : 0.0
#     sw_mode : beta
#     eta_coeff : 55
#     sw_coeff : eq_dist
#     sw_coeff_minmax : 0.02
#     sw_coeff_postmap : <function <lambda> at 0x000001379C239040>
#     price_fluct : 0.001
#     reference_price : last
#     subaction_par : 0.0
#   0%|          | 0/11 [00:00<?, ?it/s]
